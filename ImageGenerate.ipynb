# %%
import numpy as np

import os

from PIL import Image as im

import matplotlib.pyplot as plt

# %%
characterImage = r"C:\Users\pauld\PycharmProjects\DeepCRMFYP\Source Code\Character\Users\pauld\PycharmProjects\DeepCRMFYP\RankedClasses\results_2mid\CumulativeSumAggregatorTests.java.matrix"
nodeImage = r"C:\Users\pauld\PycharmProjects\DeepCRMFYP\Source Code\Node\Users\pauld\PycharmProjects\DeepCRMFYP\RankedClasses\results_2mid\CumulativeSumAggregatorTests.java.matrix"
tokenImage = r"C:\Users\pauld\PycharmProjects\DeepCRMFYP\Source Code\Token\Users\pauld\PycharmProjects\DeepCRMFYP\RankedClasses\results_2mid\CumulativeSumAggregatorTests.java.matrix"

characterImageMatrix = []
nodeImageMatrix = []
tokenImageMatrix = []

# %%
matrix = []
with open(characterImage, 'r') as f:
    matrix = [[int(num) + 1 for num in line.split(',') if num != "\n"][:153] for line in f ]
    characterImageMatrix = np.array(matrix)

matrix = []
with open(nodeImage, 'r') as f:
    matrix = [[int(num) + 1 for num in line.split(',') if num != "\n"][:153] for line in f ]
    nodeImageMatrix = np.array(matrix)

matrix = []
with open(tokenImage, 'r') as f:
    matrix = [[int(num) + 1 for num in line.split(',') if num != "\n"][:153] for line in f ]
    tokenImageMatrix = np.array(matrix)

# %%
plt.imshow(characterImageMatrix)

# %%
plt.imshow(nodeImageMatrix)

# %%
plt.imshow(tokenImageMatrix)
